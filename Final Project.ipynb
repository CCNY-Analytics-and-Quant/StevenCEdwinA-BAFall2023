# %%
#importing libraries
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Converted SQL results from Azure Data Studio to .CSV files due to it being a more reliable way to load in the data. Trying to load in the data from SQL using the library 'SQLAlchemy' did not work. (Credit to Steven Fernandez for giving me this solution.)
# Loading the data to make sure there are no potential data viewing issues in the future.

# Labeled as 'dfCD' -> dataframe Customer Data
dfCD = pd.read_csv('Results_CustomerData.csv') 
dfCD
# Out:
#       Customer_City Customer_Country Customer_Fname Customer_Lname  \
# 0         Aguadilla      Puerto Rico         Brenna         Wilson
# 1         Aguadilla      Puerto Rico      Christina          Smith
# 2         Aguadilla      Puerto Rico     Jacqueline          Smith
# 3         Aguadilla      Puerto Rico           Mary            Lee
# 4         Aguadilla      Puerto Rico           Mary        Mendoza
# ...             ...              ...            ...            ...
# 20623    Zanesville          EE. UU.           Mary        Garrett
# 20624    Zanesville          EE. UU.           Mary          Lopez
# 20625    Zanesville          EE. UU.        Matthew          Smith
# 20626    Zanesville          EE. UU.       Victoria          Smith
# 20627    Zanesville          EE. UU.        William         Dawson
#
#                Customer_Street  Customer_Zipcode Customer_State
# 0              1819 Noble Ramp             603.0             PR
# 1      5247 Cotton Cider Trace             603.0             PR
# 2       2514 Green Quail Falls             603.0             PR
# 3         7381 Green Autoroute             603.0             PR
# 4          2264 Silent Freeway             603.0             PR
# ...                        ...               ...            ...
# 20623      6324 Jagged Orchard           43701.0             OH
# 20624        9340 Sleepy Acres           43701.0             OH
# 20625        1381 Cozy Oak Key           43701.0             OH
# 20626  6217 Rustic Lake Forest           43701.0             OH
# 20627         3754 Foggy Jetty           43701.0             OH
#
# [20628 rows x 7 columns]

# %%
# Labeled as 'dfOD' -> dataframe Order Data
dfOD = pd.read_csv('Results_OrderData.csv')
dfOD
# Out:
#               order_date_DateOrders  Order_Item_Product_Price  \
# 0       2015-01-01 00:00:00.0000000                299.980011
# 1       2015-01-01 00:21:00.0000000                129.990005
# 2       2015-01-01 00:21:00.0000000                199.990005
# 3       2015-01-01 00:21:00.0000000                 50.000000
# 4       2015-01-01 01:03:00.0000000                 24.990000
# ...                             ...                       ...
# 180514  2018-01-31 22:14:00.0000000                215.820007
# 180515  2018-01-31 22:35:00.0000000                215.820007
# 180516  2018-01-31 22:56:00.0000000                327.750000
# 180517  2018-01-31 23:17:00.0000000                 11.540000
# 180518  2018-01-31 23:38:00.0000000                 39.750000
#
#         Order_Item_Total     Order_Region       Sales      Type  \
# 0             239.979996  Central America  299.980011      CASH
# 1             107.889999    South America  129.990005   PAYMENT
# 2             193.990005    South America  199.990005   PAYMENT
# 3             227.500000    South America  250.000000   PAYMENT
# 4              40.980000    South America   49.980000      CASH
# ...                  ...              ...         ...       ...
# 180514        161.869995   Southeast Asia  215.820007  TRANSFER
# 180515        172.660004   Southeast Asia  215.820007     DEBIT
# 180516        314.640015   Southeast Asia  327.750000     DEBIT
# 180517         10.910000   Southeast Asia   11.540000   PAYMENT
# 180518         34.980000          Oceania   39.750000      CASH
#
#         Order_Item_Discount
# 0                 60.000000
# 1                 22.100000
# 2                  6.000000
# 3                 22.500000
# 4                  9.000000
# ...                     ...
# 180514            53.959999
# 180515            43.160000
# 180516            13.110000
# 180517             0.630000
# 180518             4.770000
#
# [180519 rows x 7 columns]

# %%
# Labeled as 'dfPD' -> dataframe Product Data
dfPD = pd.read_csv('Results_ProductData.csv')
dfPD
# Out:
#           Category_Name                                   Product_Name  \
# 0           Accessories     Team Golf New England Patriots Putter Grip
# 1           Accessories      Team Golf Pittsburgh Steelers Putter Grip
# 2           Accessories     Team Golf San Francisco Giants Putter Grip
# 3           Accessories      Team Golf St. Louis Cardinals Putter Grip
# 4           Accessories     Team Golf Tennessee Volunteers Putter Grip
# ..                  ...                                            ...
# 113     Women's Apparel           Nike Men's Dri-FIT Victory Golf Polo
# 114    Women's Clothing                                 Summer dresses
# 115  Women's Golf Clubs  Cleveland Golf Collegiate My Custom Wedge 588
# 116  Women's Golf Clubs              MDGolf Pittsburgh Penguins Putter
# 117  Women's Golf Clubs            TaylorMade White Smoke IN-12 Putter
#
#      Product_Price
# 0        24.990000
# 1        24.990000
# 2        24.990000
# 3        24.990000
# 4        24.990000
# ..             ...
# 113      50.000000
# 114     215.820007
# 115     209.990005
# 116      79.989998
# 117      99.989998
#
# [118 rows x 3 columns]

# %%
dfPD.dtypes
# Out:
# Category_Name     object
# Product_Name      object
# Product_Price    float64
# dtype: object

# %%
# Labeled as 'dfShipD' -> dataframe Shipping Data
dfShipD = pd.read_csv('Results_ShippingData.csv')
dfShipD
# Out:
#      Days_for_shipment_scheduled  Days_for_shipping_real    Delivery_Status  \
# 0                              0                       0  Shipping canceled
# 1                              0                       0   Shipping on time
# 2                              0                       0  Shipping canceled
# 3                              0                       0  Shipping canceled
# 4                              0                       0  Shipping canceled
# ..                           ...                     ...                ...
# 125                            4                       3  Shipping canceled
# 126                            4                       6  Shipping canceled
# 127                            4                       5      Late delivery
# 128                            4                       6  Shipping canceled
# 129                            4                       4   Shipping on time
#
#       Shipping_Mode        Market
# 0          Same Day         LATAM
# 1          Same Day        Africa
# 2          Same Day        Africa
# 3          Same Day  Pacific Asia
# 4          Same Day        Europe
# ..              ...           ...
# 125  Standard Class          USCA
# 126  Standard Class        Europe
# 127  Standard Class  Pacific Asia
# 128  Standard Class  Pacific Asia
# 129  Standard Class          USCA
#
# [130 rows x 5 columns]

# %%
# Labeled as 'dfStoreD' -> dataframe Store Data
dfStoreD = pd.read_csv('Results_StoreData.csv')
dfStoreD
# Out:
#        Department_Name  Department_Id
# 0             Fan Shop              7
# 1             Pet Shop             11
# 2             Outdoors              6
# 3              Apparel              4
# 4                 Golf              5
# 5            Book Shop              8
# 6           Discs Shop              9
# 7             Footwear              3
# 8              Fitness              2
# 9           Technology             10
# 10  Health and Beauty              12

# %%
# Double checking the columns that exist in each dataframe to ensure nothing else needs to be cleaned.
dfStoreD.columns
# Out:
# Index(['Department_Name', 'Department_Id'], dtype='object')

# %%
dfShipD.columns
# Out:
# Index(['Days_for_shipment_scheduled', 'Days_for_shipping_real',
#        'Delivery_Status', 'Shipping_Mode', 'Market'],
#       dtype='object')

# %%
dfPD.columns
# Out:
# Index(['Category_Name', 'Product_Name', 'Product_Price'], dtype='object')

# %%
dfOD.columns
# Out:
# Index(['order_date_DateOrders', 'Order_Item_Product_Price', 'Order_Item_Total',
#        'Order_Region', 'Sales', 'Type', 'Order_Item_Discount'],
#       dtype='object')

# %%
dfCD.columns
# Out:
# Index(['Customer_City', 'Customer_Country', 'Customer_Fname', 'Customer_Lname',
#        'Customer_Street', 'Customer_Zipcode', 'Customer_State'],
#       dtype='object')

# %%
# Loading dataframe again so I don't have to scroll up
dfOD = pd.read_csv('Results_OrderData.csv')
dfOD
# Out:
#               order_date_DateOrders  Order_Item_Product_Price  \
# 0       2015-01-01 00:00:00.0000000                299.980011
# 1       2015-01-01 00:21:00.0000000                129.990005
# 2       2015-01-01 00:21:00.0000000                199.990005
# 3       2015-01-01 00:21:00.0000000                 50.000000
# 4       2015-01-01 01:03:00.0000000                 24.990000
# ...                             ...                       ...
# 180514  2018-01-31 22:14:00.0000000                215.820007
# 180515  2018-01-31 22:35:00.0000000                215.820007
# 180516  2018-01-31 22:56:00.0000000                327.750000
# 180517  2018-01-31 23:17:00.0000000                 11.540000
# 180518  2018-01-31 23:38:00.0000000                 39.750000
#
#         Order_Item_Total     Order_Region       Sales      Type  \
# 0             239.979996  Central America  299.980011      CASH
# 1             107.889999    South America  129.990005   PAYMENT
# 2             193.990005    South America  199.990005   PAYMENT
# 3             227.500000    South America  250.000000   PAYMENT
# 4              40.980000    South America   49.980000      CASH
# ...                  ...              ...         ...       ...
# 180514        161.869995   Southeast Asia  215.820007  TRANSFER
# 180515        172.660004   Southeast Asia  215.820007     DEBIT
# 180516        314.640015   Southeast Asia  327.750000     DEBIT
# 180517         10.910000   Southeast Asia   11.540000   PAYMENT
# 180518         34.980000          Oceania   39.750000      CASH
#
#         Order_Item_Discount
# 0                 60.000000
# 1                 22.100000
# 2                  6.000000
# 3                 22.500000
# 4                  9.000000
# ...                     ...
# 180514            53.959999
# 180515            43.160000
# 180516            13.110000
# 180517             0.630000
# 180518             4.770000
#
# [180519 rows x 7 columns]

# %%
# Summing up product prices and sorted by regions from greatest amount of money made to least. Western Europe has the greatest value of total sales while Western Europe has the least.
# Group by 'Region' and sum the 'Sales' for each region
region_sales_sum = dfOD.groupby('Order_Region')['Sales'].sum().reset_index()

# Sort the summed sales values in descending order
sorted_sales = region_sales_sum.sort_values(by='Sales', ascending=False)

# Identify regions that made the most and least money
region_most_money = sorted_sales.iloc[0]  # Region with the most money
region_least_money = sorted_sales.iloc[-1]  # Region with the least money

print("Region making the most money:")
print(region_most_money)
print("\nRegion making the least money:")
print(region_least_money)
# Out:
# Region making the most money:
# Order_Region    Western Europe
# Sales            5894380.76507
# Name: 22, dtype: object
#
# Region making the least money:
# Order_Region     Central Asia
# Sales           109839.932196
# Name: 4, dtype: object

# %%
# Visualization of the distribution of total sales per region.
plt.figure(figsize=(10, 6))
plt.bar(sorted_sales['Order_Region'], sorted_sales['Sales'])
plt.xticks(rotation=45)
plt.ylabel('Sales')
plt.xlabel('Regions')
plt.title('Total Sales by Region')
plt.tight_layout()
plt.show()

# %%
# Realization that the 'Order_Proft_Per_Order' category has some negatives, will need to create visualization to the trend.
dfOD2 = pd.read_csv('Results_OrderData2.csv')
dfOD2
# Out:
#               order_date_DateOrders  Order_Item_Product_Price  \
# 0       2015-01-01 00:00:00.0000000                299.980011
# 1       2015-01-01 00:21:00.0000000                129.990005
# 2       2015-01-01 00:21:00.0000000                199.990005
# 3       2015-01-01 00:21:00.0000000                 50.000000
# 4       2015-01-01 01:03:00.0000000                 24.990000
# ...                             ...                       ...
# 180514  2018-01-31 22:14:00.0000000                215.820007
# 180515  2018-01-31 22:35:00.0000000                215.820007
# 180516  2018-01-31 22:56:00.0000000                327.750000
# 180517  2018-01-31 23:17:00.0000000                 11.540000
# 180518  2018-01-31 23:38:00.0000000                 39.750000
#
#         Order_Item_Total     Order_Region       Sales      Type  \
# 0             239.979996  Central America  299.980011      CASH
# 1             107.889999    South America  129.990005   PAYMENT
# 2             193.990005    South America  199.990005   PAYMENT
# 3             227.500000    South America  250.000000   PAYMENT
# 4              40.980000    South America   49.980000      CASH
# ...                  ...              ...         ...       ...
# 180514        161.869995   Southeast Asia  215.820007  TRANSFER
# 180515        172.660004   Southeast Asia  215.820007     DEBIT
# 180516        314.640015   Southeast Asia  327.750000     DEBIT
# 180517         10.910000   Southeast Asia   11.540000   PAYMENT
# 180518         34.980000          Oceania   39.750000      CASH
#
#         Order_Item_Discount  Order_Profit_Per_Order
# 0                 60.000000               88.790001
# 1                 22.100000               36.470001
# 2                  6.000000               91.180000
# 3                 22.500000               68.250000
# 4                  9.000000                4.100000
# ...                     ...                     ...
# 180514            53.959999             -107.959999
# 180515            43.160000             -126.559998
# 180516            13.110000               91.250000
# 180517             0.630000                1.530000
# 180518             4.770000                9.790000
#
# [180519 rows x 8 columns]

# %%
# Credit to Steven Fernandez's code.

# Convert 'order_date_DateOrders' column to datetime
dfOD2['order_date_DateOrders'] = pd.to_datetime(dfOD2['order_date_DateOrders'])

# Select columns and convert 'Order_Profit_Per_Order' to numeric using .loc
profitOverTime = dfOD2[['order_date_DateOrders', 'Order_Profit_Per_Order']].copy()
profitOverTime.loc[:, 'Order_Profit_Per_Order'] = pd.to_numeric(profitOverTime['Order_Profit_Per_Order'])

# Set 'order_date_DateOrders' as the index
profitOverTime.set_index('order_date_DateOrders', inplace=True)

# Ensure the index is a DatetimeIndex
profitOverTime.index = pd.to_datetime(profitOverTime.index)

# Resample by month ('M') and sum the profits
profitTrend = profitOverTime['Order_Profit_Per_Order'].resample('M').sum()

profitTrend = profitOverTime['Order_Profit_Per_Order'].resample('M').sum()
profitTrend.head
# Out:
# <bound method NDFrame.head of order_date_DateOrders
# 2015-01-31    111660.740132
# 2015-02-28     99140.660196
# 2015-03-31    113778.210191
# 2015-04-30    108083.679957
# 2015-05-31    112147.900143
# 2015-06-30    110147.160313
# 2015-07-31    115624.059879
# 2015-08-31    117979.770302
# 2015-09-30    113467.940118
# 2015-10-31    101757.870040
# 2015-11-30    104427.360120
# 2015-12-31    110641.549881
# 2016-01-31    106780.950229
# 2016-02-29     86809.490642
# 2016-03-31    101259.990250
# 2016-04-30    114976.619907
# 2016-05-31    110716.120111
# 2016-06-30    104196.070108
# 2016-07-31    119941.720183
# 2016-08-31    110729.540117
# 2016-09-30    123384.709977
# 2016-10-31    116781.970048
# 2016-11-30    109539.199962
# 2016-12-31    105002.689937
# 2017-01-31    114843.850277
# 2017-02-28    115111.070097
# 2017-03-31    118688.900211
# 2017-04-30    115961.060193
# 2017-05-31    115014.640014
# 2017-06-30    110399.290305
# 2017-07-31    113026.700038
# 2017-08-31    131501.160211
# 2017-09-30    122462.390153
# 2017-10-31    113447.169883
# 2017-11-30     67791.250205
# 2017-12-31     65837.629745
# 2018-01-31     33841.889977
# Freq: M, Name: Order_Profit_Per_Order, dtype: float64>

# %%
# Visualization on how the profit has changed from 2015 - 2018. Can see that profits 9/2017 and then started to decline rapidly.
plt.figure(figsize=(24, 12))
plt.plot(profitTrend.index, profitTrend.values, label='Monthly Profit Trend Line')
plt.title('Profit Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Loading the uncleaned data back in for cleaning due to cleaning on pandas being more reliable than SQL. 
dfODA = pd.read_csv('Results_OrderDataAll.csv')
dfODA
# Out:
#         column1  Benefit_per_order  Order_City Order_Country  \
# 0             0          91.250000      Bekasi     Indonesia
# 1             1        -249.089996     Bikaner         India
# 2             2        -247.779999     Bikaner         India
# 3             3          22.860001  Townsville     Australia
# 4             4         134.210007  Townsville     Australia
# ...         ...                ...         ...           ...
# 180514   180514          40.000000    Shanghái         China
# 180515   180515        -613.770020    Hirakata         Japón
# 180516   180516         141.110001    Adelaide     Australia
# 180517   180517         186.229996    Adelaide     Australia
# 180518   180518         168.949997   Nagercoil         India
#
#         Order_Customer_Id        order_date_DateOrders  Order_Id  \
# 0                   20755  2018-01-31 22:56:00.0000000     77202
# 1                   19492  2018-01-13 12:27:00.0000000     75939
# 2                   19491  2018-01-13 12:06:00.0000000     75938
# 3                   19490  2018-01-13 11:45:00.0000000     75937
# 4                   19489  2018-01-13 11:24:00.0000000     75936
# ...                   ...                          ...       ...
# 180514               1005  2016-01-16 03:40:00.0000000     26043
# 180515               9141  2016-01-16 01:34:00.0000000     26037
# 180516                291  2016-01-15 21:00:00.0000000     26024
# 180517               2813  2016-01-15 20:18:00.0000000     26022
# 180518               7547  2016-01-15 18:54:00.0000000     26018
#
#         Order_Item_Cardprod_Id  Order_Item_Discount  Order_Item_Discount_Rate  \
# 0                         1360            13.110000                      0.04
# 1                         1360            16.389999                      0.05
# 2                         1360            18.030001                      0.06
# 3                         1360            22.940001                      0.07
# 4                         1360            29.500000                      0.09
# ...                        ...                  ...                       ...
# 180514                    1004             0.000000                      0.00
# 180515                    1004             4.000000                      0.01
# 180516                    1004             8.000000                      0.02
# 180517                    1004            12.000000                      0.03
# 180518                    1004            16.000000                      0.04
#
#         ...  Order_Item_Profit_Ratio  Order_Item_Quantity  Order_Item_Total  \
# 0       ...                     0.29                    1        314.640015
# 1       ...                    -0.80                    1        311.359985
# 2       ...                    -0.80                    1        309.720001
# 3       ...                     0.08                    1        304.809998
# 4       ...                     0.45                    1        298.250000
# ...     ...                      ...                  ...               ...
# 180514  ...                     0.10                    1        399.980011
# 180515  ...                    -1.55                    1        395.980011
# 180516  ...                     0.36                    1        391.980011
# 180517  ...                     0.48                    1        387.980011
# 180518  ...                     0.44                    1        383.980011
#
#         Order_Profit_Per_Order    Order_Region        Order_State  \
# 0                    91.250000  Southeast Asia    Java Occidental
# 1                  -249.089996      South Asia           Rajastán
# 2                  -247.779999      South Asia           Rajastán
# 3                    22.860001         Oceania         Queensland
# 4                   134.210007         Oceania         Queensland
# ...                        ...             ...                ...
# 180514               40.000000    Eastern Asia           Shanghái
# 180515             -613.770019    Eastern Asia              Osaka
# 180516              141.110001         Oceania  Australia del Sur
# 180517              186.229996         Oceania  Australia del Sur
# 180518              168.949997      South Asia         Tamil Nadu
#
#            Order_Status Order_Zipcode       Sales      Type
# 0              COMPLETE           NaN  327.750000     DEBIT
# 1               PENDING           NaN  327.750000  TRANSFER
# 2                CLOSED           NaN  327.750000      CASH
# 3              COMPLETE           NaN  327.750000     DEBIT
# 4       PENDING_PAYMENT           NaN  327.750000   PAYMENT
# ...                 ...           ...         ...       ...
# 180514           CLOSED           NaN  399.980011      CASH
# 180515         COMPLETE           NaN  399.980011     DEBIT
# 180516          PENDING           NaN  399.980011  TRANSFER
# 180517  PENDING_PAYMENT           NaN  399.980011   PAYMENT
# 180518  PENDING_PAYMENT           NaN  399.980011   PAYMENT
#
# [180519 rows x 22 columns]

# %%
# Cleaning what's unnecessary to figure out the next step. Which is the item distribution for most ordered items.
columnstoDrop = ['column1', 'Benefit_per_order', 'Order_City', 'Order_Country', 'Order_Customer_Id', 'Order_Id', 'Order_Item_Cardprod_Id', 'Order_Item_Profit_Ratio', 'Order_State', 'Order_Zipcode']
dfODA.drop(columnstoDrop, axis = 1, inplace = True)
dfODA
# Out:
#               order_date_DateOrders  Order_Item_Discount  \
# 0       2018-01-31 22:56:00.0000000            13.110000
# 1       2018-01-13 12:27:00.0000000            16.389999
# 2       2018-01-13 12:06:00.0000000            18.030001
# 3       2018-01-13 11:45:00.0000000            22.940001
# 4       2018-01-13 11:24:00.0000000            29.500000
# ...                             ...                  ...
# 180514  2016-01-16 03:40:00.0000000             0.000000
# 180515  2016-01-16 01:34:00.0000000             4.000000
# 180516  2016-01-15 21:00:00.0000000             8.000000
# 180517  2016-01-15 20:18:00.0000000            12.000000
# 180518  2016-01-15 18:54:00.0000000            16.000000
#
#         Order_Item_Discount_Rate  Order_Item_Id  Order_Item_Product_Price  \
# 0                           0.04         180517                327.750000
# 1                           0.05         179254                327.750000
# 2                           0.06         179253                327.750000
# 3                           0.07         179252                327.750000
# 4                           0.09         179251                327.750000
# ...                          ...            ...                       ...
# 180514                      0.00          65177                399.980011
# 180515                      0.01          65161                399.980011
# 180516                      0.02          65129                399.980011
# 180517                      0.03          65126                399.980011
# 180518                      0.04          65113                399.980011
#
#         Order_Item_Quantity  Order_Item_Total  Order_Profit_Per_Order  \
# 0                         1        314.640015               91.250000
# 1                         1        311.359985             -249.089996
# 2                         1        309.720001             -247.779999
# 3                         1        304.809998               22.860001
# 4                         1        298.250000              134.210007
# ...                     ...               ...                     ...
# 180514                    1        399.980011               40.000000
# 180515                    1        395.980011             -613.770019
# 180516                    1        391.980011              141.110001
# 180517                    1        387.980011              186.229996
# 180518                    1        383.980011              168.949997
#
#           Order_Region     Order_Status       Sales      Type
# 0       Southeast Asia         COMPLETE  327.750000     DEBIT
# 1           South Asia          PENDING  327.750000  TRANSFER
# 2           South Asia           CLOSED  327.750000      CASH
# 3              Oceania         COMPLETE  327.750000     DEBIT
# 4              Oceania  PENDING_PAYMENT  327.750000   PAYMENT
# ...                ...              ...         ...       ...
# 180514    Eastern Asia           CLOSED  399.980011      CASH
# 180515    Eastern Asia         COMPLETE  399.980011     DEBIT
# 180516         Oceania          PENDING  399.980011  TRANSFER
# 180517         Oceania  PENDING_PAYMENT  399.980011   PAYMENT
# 180518      South Asia  PENDING_PAYMENT  399.980011   PAYMENT
#
# [180519 rows x 12 columns]

# %%
# Checking what the most sold products are

# Reloading Product Data to reduce the amount of scrolling required. Product Data will tell us the product name and category it belongs in.
dfPD = pd.read_csv('Results_ProductData.csv')
dfPD
# Out:
#           Category_Name                                   Product_Name  \
# 0           Accessories     Team Golf New England Patriots Putter Grip
# 1           Accessories      Team Golf Pittsburgh Steelers Putter Grip
# 2           Accessories     Team Golf San Francisco Giants Putter Grip
# 3           Accessories      Team Golf St. Louis Cardinals Putter Grip
# 4           Accessories     Team Golf Tennessee Volunteers Putter Grip
# ..                  ...                                            ...
# 113     Women's Apparel           Nike Men's Dri-FIT Victory Golf Polo
# 114    Women's Clothing                                 Summer dresses
# 115  Women's Golf Clubs  Cleveland Golf Collegiate My Custom Wedge 588
# 116  Women's Golf Clubs              MDGolf Pittsburgh Penguins Putter
# 117  Women's Golf Clubs            TaylorMade White Smoke IN-12 Putter
#
#      Product_Price
# 0        24.990000
# 1        24.990000
# 2        24.990000
# 3        24.990000
# 4        24.990000
# ..             ...
# 113      50.000000
# 114     215.820007
# 115     209.990005
# 116      79.989998
# 117      99.989998
#
# [118 rows x 3 columns]

# %%
# Checking what the most sold products are

# Column containing the items to count
itemCounts = dfPD['Category_Name'].value_counts()

# Plotting a pie chart
plt.figure(figsize=(40, 44))  # Set the size of the figure
plt.pie(itemCounts, labels = itemCounts.index, autopct = '%1.1f%%', startangle = 180, textprops = {'color': 'white'})
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of Items', color = 'white', fontdict = {'fontsize': 30, 'fontweight': 'bold'})  # Set the title of the pie chart

# Show the pie chart
plt.show()


print('It can be seen that the top 5 most sold products are electronics, kids golf clubs, golf gloves, accessories, and golf balls.')
# Out:
# It can be seen that the top 5 most sold products are electronics, kids golf clubs, golf gloves, accessories, and golf balls.

# %%
# Now need to figure out the actual costs from the data. But there's no explicit data for it so we have to do some math.
productCost = dfODA[['order_date_DateOrders', 'Order_Region', 'Order_Profit_Per_Order', 'Order_Item_Total']]
productCost
# Out:
#               order_date_DateOrders    Order_Region  Order_Profit_Per_Order  \
# 0       2018-01-31 22:56:00.0000000  Southeast Asia               91.250000
# 1       2018-01-13 12:27:00.0000000      South Asia             -249.089996
# 2       2018-01-13 12:06:00.0000000      South Asia             -247.779999
# 3       2018-01-13 11:45:00.0000000         Oceania               22.860001
# 4       2018-01-13 11:24:00.0000000         Oceania              134.210007
# ...                             ...             ...                     ...
# 180514  2016-01-16 03:40:00.0000000    Eastern Asia               40.000000
# 180515  2016-01-16 01:34:00.0000000    Eastern Asia             -613.770019
# 180516  2016-01-15 21:00:00.0000000         Oceania              141.110001
# 180517  2016-01-15 20:18:00.0000000         Oceania              186.229996
# 180518  2016-01-15 18:54:00.0000000      South Asia              168.949997
#
#         Order_Item_Total
# 0             314.640015
# 1             311.359985
# 2             309.720001
# 3             304.809998
# 4             298.250000
# ...                  ...
# 180514        399.980011
# 180515        395.980011
# 180516        391.980011
# 180517        387.980011
# 180518        383.980011
#
# [180519 rows x 4 columns]

# %%
# Item Total: Revenue - Profit = Cost (Warning is fine)
productCost['Cost'] = productCost['Order_Item_Total'] - productCost['Order_Profit_Per_Order']
productCost
# Out:
# /tmp/ipykernel_487142/2408651215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productCost['Cost'] = productCost['Order_Item_Total'] - productCost['Order_Profit_Per_Order']
#               order_date_DateOrders    Order_Region  Order_Profit_Per_Order  \
# 0       2018-01-31 22:56:00.0000000  Southeast Asia               91.250000
# 1       2018-01-13 12:27:00.0000000      South Asia             -249.089996
# 2       2018-01-13 12:06:00.0000000      South Asia             -247.779999
# 3       2018-01-13 11:45:00.0000000         Oceania               22.860001
# 4       2018-01-13 11:24:00.0000000         Oceania              134.210007
# ...                             ...             ...                     ...
# 180514  2016-01-16 03:40:00.0000000    Eastern Asia               40.000000
# 180515  2016-01-16 01:34:00.0000000    Eastern Asia             -613.770019
# 180516  2016-01-15 21:00:00.0000000         Oceania              141.110001
# 180517  2016-01-15 20:18:00.0000000         Oceania              186.229996
# 180518  2016-01-15 18:54:00.0000000      South Asia              168.949997
#
#         Order_Item_Total         Cost
# 0             314.640015   223.390015
# 1             311.359985   560.449982
# 2             309.720001   557.500000
# 3             304.809998   281.949997
# 4             298.250000   164.039993
# ...                  ...          ...
# 180514        399.980011   359.980011
# 180515        395.980011  1009.750030
# 180516        391.980011   250.870010
# 180517        387.980011   201.750015
# 180518        383.980011   215.030014
#
# [180519 rows x 5 columns]

# %%
# Ran into a consistent issue where KeyError: 'order_date_DateOrders' kept occurring. Used to check the index of the dataframe productCost. Some errors can be solved through running the right cells (KEEP IN MIND)
print(productCost.columns)
# Out:
# Index(['order_date_DateOrders', 'Order_Region', 'Order_Profit_Per_Order',
#        'Order_Item_Total', 'Cost'],
#       dtype='object')

# %%
# Graph code to see a visualization on the relationships between when the sales and costs started dropping dramatically.
productCost['order_date_DateOrders'] = pd.to_datetime(productCost['order_date_DateOrders'])

# Set 'order_date' as the index
productCost.set_index('order_date_DateOrders', inplace=True)

# Resample data to monthly frequency and calculate the sum
monthly_data = productCost.resample('M').sum()

# Plotting
plt.figure(figsize=(12, 6))

# Plot monthly sales
plt.plot(monthly_data.index, monthly_data['Order_Item_Total'], label='Monthly Sales', marker='o')

# Plot monthly costs
plt.plot(monthly_data.index, monthly_data['Cost'], label='Monthly Costs', marker='o')

plt.title('Monthly Sales & Costs of Orders Over Time')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_487142/1850327998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productCost['order_date_DateOrders'] = pd.to_datetime(productCost['order_date_DateOrders'])

# %%
dfShipD
# Out:
#      Days_for_shipment_scheduled  Days_for_shipping_real    Delivery_Status  \
# 0                              0                       0  Shipping canceled
# 1                              0                       0   Shipping on time
# 2                              0                       0  Shipping canceled
# 3                              0                       0  Shipping canceled
# 4                              0                       0  Shipping canceled
# ..                           ...                     ...                ...
# 125                            4                       3  Shipping canceled
# 126                            4                       6  Shipping canceled
# 127                            4                       5      Late delivery
# 128                            4                       6  Shipping canceled
# 129                            4                       4   Shipping on time
#
#       Shipping_Mode        Market
# 0          Same Day         LATAM
# 1          Same Day        Africa
# 2          Same Day        Africa
# 3          Same Day  Pacific Asia
# 4          Same Day        Europe
# ..              ...           ...
# 125  Standard Class          USCA
# 126  Standard Class        Europe
# 127  Standard Class  Pacific Asia
# 128  Standard Class  Pacific Asia
# 129  Standard Class          USCA
#
# [130 rows x 5 columns]

# %%
dfShipD.dtypes
# Out:
# Days_for_shipment_scheduled     int64
# Days_for_shipping_real          int64
# Delivery_Status                object
# Shipping_Mode                  object
# Market                         object
# dtype: object

# %%
dfShipD.columns
# Out:
# Index(['Days_for_shipment_scheduled', 'Days_for_shipping_real',
#        'Delivery_Status', 'Shipping_Mode', 'Market'],
#       dtype='object')

# %%
# Filtering shipping data to see which market, status, and shipping mode deliveries are
df_shipping_data_all = pd.read_csv('Results_ShippingDataAll2.csv')
deliveryStatus = df_shipping_data_all[['Delivery_Status', 'Shipping_Mode', 'Market']]
deliveryStatus
# Out:
#          Delivery_Status   Shipping_Mode        Market
# 0       Advance shipping  Standard Class  Pacific Asia
# 1          Late delivery  Standard Class  Pacific Asia
# 2       Shipping on time  Standard Class  Pacific Asia
# 3       Advance shipping  Standard Class  Pacific Asia
# 4       Advance shipping  Standard Class  Pacific Asia
# ...                  ...             ...           ...
# 65747      Late delivery     First Class  Pacific Asia
# 65748   Shipping on time  Standard Class  Pacific Asia
# 65749      Late delivery    Second Class  Pacific Asia
# 65750   Advance shipping  Standard Class  Pacific Asia
# 65751  Shipping canceled  Standard Class  Pacific Asia
#
# [65752 rows x 3 columns]

# %%
# Filter data for 'Shipping on time' deliveries
on_time_deliveries = deliveryStatus[df_shipping_data_all['Delivery_Status'] == 'Shipping on time']

# Group by 'Market' and count on-time deliveries
on_time_counts = on_time_deliveries.groupby('Market')['Delivery_Status'].count().reset_index(name='On Time Deliveries')

# Print to check the content of on_time_counts DataFrame
print(on_time_counts)
print('\n')

# Sort markets by the count of on-time deliveries in descending order
on_time_counts = on_time_counts.sort_values(by='On Time Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(on_time_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(on_time_counts['Market'], on_time_counts['On Time Deliveries'], color='green')
plt.xlabel('Market')
plt.ylabel('Count of On-Time Deliveries')
plt.title('Count of On-Time Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
#          Market  On Time Deliveries
# 0        Africa                 713
# 1        Europe                3250
# 2         LATAM                3085
# 3  Pacific Asia                3126
# 4          USCA                1548
#
#
#          Market  On Time Deliveries
# 1        Europe                3250
# 3  Pacific Asia                3126
# 2         LATAM                3085
# 4          USCA                1548
# 0        Africa                 713

# %%
# The Results_ShippingDataAll.csv file kept giving me an empty dataset. Had to go back into SQL and get a fresh csv file.

# Filter data for 'Late delivery' in column 'Delivery_Status' in dataframe 'df_shipping_data_all'.
late_deliveries = deliveryStatus[df_shipping_data_all['Delivery_Status'] == 'Late delivery']

# Group by 'Market' and late deliveries
late_delivery_counts = late_deliveries.groupby('Market')['Delivery_Status'].count().reset_index(name='Late Deliveries')

# Print to check the content of late_delivery_counts DataFrame
print(late_delivery_counts)
print('\n')

# Sort markets by the count of late deliveries in descending order
late_delivery_counts = late_delivery_counts.sort_values(by='Late Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(late_delivery_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(late_delivery_counts['Market'], late_delivery_counts['Late Deliveries'], color='goldenrod')
plt.xlabel('Market')
plt.ylabel('Count of Late Deliveries')
plt.title('Count of Late Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

print('We can see that the ratio of on-time deliveries to late deliveries. There are more late deliveries than on-time.')
# Out:
#          Market  Late Deliveries
# 0        Africa             2086
# 1        Europe            10199
# 2         LATAM             9339
# 3  Pacific Asia             9720
# 4          USCA             4704
#
#
#          Market  Late Deliveries
# 1        Europe            10199
# 3  Pacific Asia             9720
# 2         LATAM             9339
# 4          USCA             4704
# 0        Africa             2086
# We can see that the ratio of on-time deliveries to late deliveries. There are more late deliveries than on-time.

# %%
# Filter data for 'Canceled' deliveries
canceled_deliveries = deliveryStatus[df_shipping_data_all['Delivery_Status'] == 'Shipping canceled']

# Group by 'Market' and count canceled deliveries
canceled_delivery_counts = canceled_deliveries.groupby('Market')['Delivery_Status'].count().reset_index(name='Canceled Deliveries')

# Print to check the content of canceled_delivery_counts DataFrame
print(canceled_delivery_counts)
print('\n')

# Sort markets by the count of canceled deliveries in descending order
canceled_delivery_counts = canceled_delivery_counts.sort_values(by='Canceled Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(canceled_delivery_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(canceled_delivery_counts['Market'], canceled_delivery_counts['Canceled Deliveries'], color='red')
plt.xlabel('Market')
plt.ylabel('Count of Canceled Deliveries')
plt.title('Count of Canceled Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
#          Market  Canceled Deliveries
# 0        Africa                  165
# 1        Europe                  798
# 2         LATAM                  767
# 3  Pacific Asia                  724
# 4          USCA                  401
#
#
#          Market  Canceled Deliveries
# 1        Europe                  798
# 2         LATAM                  767
# 3  Pacific Asia                  724
# 4          USCA                  401
# 0        Africa                  165

# %%
# Filtering out data to now check the shipping modes the orders were ordered in
shippingClass = deliveryStatus[df_shipping_data_all['Shipping_Mode'] == 'First Class']

# Group by 'Market' and count canceled deliveries
shipping_class_counts = shippingClass.groupby('Market')['Shipping_Mode'].count().reset_index(name='First Class Deliveries')

# Print to check the content of canceled_delivery_counts DataFrame
print(shipping_class_counts)
print('\n')

# Sort markets by the count of canceled deliveries in descending order
shipping_class_counts = shipping_class_counts.sort_values(by='First Class Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(shipping_class_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(shipping_class_counts['Market'], shipping_class_counts['First Class Deliveries'], color='cornflowerblue')
plt.xlabel('Market')
plt.ylabel('Count of First Class Deliveries')
plt.title('Count of First Class Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
#          Market  First Class Deliveries
# 0        Africa                     557
# 1        Europe                    2878
# 2         LATAM                    2638
# 3  Pacific Asia                    2668
# 4          USCA                    1338
#
#
#          Market  First Class Deliveries
# 1        Europe                    2878
# 3  Pacific Asia                    2668
# 2         LATAM                    2638
# 4          USCA                    1338
# 0        Africa                     557

# %%
shippingClass = deliveryStatus[df_shipping_data_all['Shipping_Mode'] == 'Second Class']

# Group by 'Market' and count second class deliveries
shipping_class_counts = shippingClass.groupby('Market')['Shipping_Mode'].count().reset_index(name='Second Class Deliveries')

# Print to check the content of shipping_class_counts DataFrame
print(shipping_class_counts)
print('\n')

# Sort markets by the count of second class deliveries in descending order
shipping_class_counts = shipping_class_counts.sort_values(by='Second Class Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(shipping_class_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(shipping_class_counts['Market'], shipping_class_counts['Second Class Deliveries'], color='orchid')
plt.xlabel('Market')
plt.ylabel('Count of Second Class Deliveries')
plt.title('Count of Second Class Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
#          Market  Second Class Deliveries
# 0        Africa                      715
# 1        Europe                     3609
# 2         LATAM                     3307
# 3  Pacific Asia                     3469
# 4          USCA                     1678
#
#
#          Market  Second Class Deliveries
# 1        Europe                     3609
# 3  Pacific Asia                     3469
# 2         LATAM                     3307
# 4          USCA                     1678
# 0        Africa                      715

# %%
shippingClass = deliveryStatus[df_shipping_data_all['Shipping_Mode'] == 'Standard Class']

# Group by 'Market' and count standard class deliveries
shipping_class_counts = shippingClass.groupby('Market')['Shipping_Mode'].count().reset_index(name='Standard Class Deliveries')

# Print to check the content of shipping_class_counts DataFrame
print(shipping_class_counts)
print('\n')

# Sort markets by the count of second class deliveries in descending order
shipping_class_counts = shipping_class_counts.sort_values(by='Standard Class Deliveries', ascending=False)

# Print to check the sorted DataFrame
print(shipping_class_counts)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(shipping_class_counts['Market'], shipping_class_counts['Standard Class Deliveries'], color='olive')
plt.xlabel('Market')
plt.ylabel('Count of Standard Class Deliveries')
plt.title('Count of Standard Class Deliveries by Market')
plt.xticks(rotation=360, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
#          Market  Standard Class Deliveries
# 0        Africa                       2348
# 1        Europe                      11075
# 2         LATAM                      10323
# 3  Pacific Asia                      10481
# 4          USCA                       5097
#
#
#          Market  Standard Class Deliveries
# 1        Europe                      11075
# 3  Pacific Asia                      10481
# 2         LATAM                      10323
# 4          USCA                       5097
# 0        Africa                       2348

# %%
# Will need to look at the profit. Only have looked at revenue and costs. 
productCost
# Out:
#                          Order_Region  Order_Profit_Per_Order  \
# order_date_DateOrders
# 2018-01-31 22:56:00    Southeast Asia               91.250000
# 2018-01-13 12:27:00        South Asia             -249.089996
# 2018-01-13 12:06:00        South Asia             -247.779999
# 2018-01-13 11:45:00           Oceania               22.860001
# 2018-01-13 11:24:00           Oceania              134.210007
# ...                               ...                     ...
# 2016-01-16 03:40:00      Eastern Asia               40.000000
# 2016-01-16 01:34:00      Eastern Asia             -613.770019
# 2016-01-15 21:00:00           Oceania              141.110001
# 2016-01-15 20:18:00           Oceania              186.229996
# 2016-01-15 18:54:00        South Asia              168.949997
#
#                        Order_Item_Total         Cost
# order_date_DateOrders
# 2018-01-31 22:56:00          314.640015   223.390015
# 2018-01-13 12:27:00          311.359985   560.449982
# 2018-01-13 12:06:00          309.720001   557.500000
# 2018-01-13 11:45:00          304.809998   281.949997
# 2018-01-13 11:24:00          298.250000   164.039993
# ...                                 ...          ...
# 2016-01-16 03:40:00          399.980011   359.980011
# 2016-01-16 01:34:00          395.980011  1009.750030
# 2016-01-15 21:00:00          391.980011   250.870010
# 2016-01-15 20:18:00          387.980011   201.750015
# 2016-01-15 18:54:00          383.980011   215.030014
#
# [180519 rows x 4 columns]

# %%
# Use Order_Profit_Per_Order and aggregate by region and sum up profit

# Group by 'Market' and count standard class deliveries
profitChart = productCost.groupby('Order_Region')['Order_Profit_Per_Order'].count().reset_index(name='Profit')

# Print to check the content of profitChart DataFrame
print(profitChart)
print('\n')

# Sort markets by the count of Profit in descending order
profitChart = profitChart.sort_values(by = 'Profit', ascending = False)

# Print to check the sorted DataFrame
print(profitChart)
# Out:
#        Order_Region  Profit
# 0            Canada     959
# 1         Caribbean    8318
# 2    Central Africa    1677
# 3   Central America   28341
# 4      Central Asia     553
# 5       East Africa    1852
# 6       East of USA    6915
# 7      Eastern Asia    7280
# 8    Eastern Europe    3920
# 9      North Africa    3232
# 10  Northern Europe    9792
# 11          Oceania   10148
# 12    South America   14935
# 13       South Asia    7731
# 14   South of  USA     4045
# 15   Southeast Asia    9539
# 16  Southern Africa    1157
# 17  Southern Europe    9431
# 18       US Center     5887
# 19      West Africa    3696
# 20        West Asia    6009
# 21     West of USA     7993
# 22   Western Europe   27109
#
#
#        Order_Region  Profit
# 3   Central America   28341
# 22   Western Europe   27109
# 12    South America   14935
# 11          Oceania   10148
# 10  Northern Europe    9792
# 15   Southeast Asia    9539
# 17  Southern Europe    9431
# 1         Caribbean    8318
# 21     West of USA     7993
# 13       South Asia    7731
# 7      Eastern Asia    7280
# 6       East of USA    6915
# 20        West Asia    6009
# 18       US Center     5887
# 14   South of  USA     4045
# 8    Eastern Europe    3920
# 19      West Africa    3696
# 9      North Africa    3232
# 5       East Africa    1852
# 2    Central Africa    1677
# 16  Southern Africa    1157
# 0            Canada     959
# 4      Central Asia     553

# %%
# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(profitChart['Order_Region'], profitChart['Profit'], color = 'green')
plt.xlabel('Order Region')
plt.ylabel('Total Profit')
plt.title('Highest Profiting Regions')
plt.xticks(rotation=90, ha='right')# Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
print('Despite Western Europe being the region that holds the most sales, it does not hold the most profit made. Which in this graph is Central America.')
